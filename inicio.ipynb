# %% [markdown]
# Conhecendo o Python
#
#
# Bem vindo(a) ao estudo da linguagem Python

# %%
x = 1
y = 2
print("X vale:", x)
print("Y vale:", y)
# Out:
# X vale: 1
# Y vale: 2

# %%
x+y
# Out:
# 3

# %%
x = "Data "
y = "Science "
print(x+y)
# Out:
# Data Science

# %%
True + True + False
# Out:
# 2

# %%
None

# %% [markdown]
# Conhecendo os Tipos

# %%
teste = 1
type(teste)
# Out:
# int

# %%
int(3.15)
# Out:
# 3

# %% [markdown]
# ## Trabalhando com o Pandas

# %%
import pandas as pd

serie = pd.Series([3,7,5,6,8])
serie
# Out:
# 0    3
# 1    7
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
serie.head(3)
# Out:
# 0    3
# 1    7
# 2    5
# dtype: int64

# %%
serie.dtype
# Out:
# dtype('int64')

# %%
serie.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
serie.value_counts()
# Out:
# 3    1
# 7    1
# 5    1
# 6    1
# 8    1
# Name: count, dtype: int64

# %%
data_int = pd.date_range("20250101", periods=6, freq="ME")

# %%
data_br = data_int.strftime("%d/%m/$Y")
data_br
# Out:
# Index(['31/01/$Y', '28/02/$Y', '31/03/$Y', '30/04/$Y', '31/05/$Y', '30/06/$Y'], dtype='object')

# %%
import numpy as np

df = pd.DataFrame(
    np.random.randint(1,5,size=(6,4)),
    index=data_br,
    columns=["A", "B", "C", "D"]
    )

# %%
df.head(3)
# Out:
#           A  B  C  D
# 31/01/$Y  3  1  3  2
# 28/02/$Y  1  2  3  2
# 31/03/$Y  4  2  4  3

# %%
df.columns = ['a', 'b', 'c', 'd']

# %%
df.columns = ['coll', 'col2', 'col3', 'col4']

# %%
df
# Out:
#           coll  col2  col3  col4
# 31/01/$Y     3     1     3     2
# 28/02/$Y     1     2     3     2
# 31/03/$Y     4     2     4     3
# 30/04/$Y     4     1     3     4
# 31/05/$Y     1     2     2     1
# 30/06/$Y     4     4     4     4
